# %% [markdown]
# # 1 Import packages

# %%
# Install the packages used in the first part of the tutorial
# %pip install networkx
# %pip install osmnx
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# Install the packages used in the third part of the tutorial
# %pip install r5py
# %pip install mapclassify
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning, module="pandas.core.frame")

# %% [markdown]
# # 2 Network extract and save

# %%
import networkx as nx
import osmnx as ox
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import geopandas as gpd
# from osgeo import gdal

# %% [markdown]
# ## 2.1 Network Extract

# %%
G1 = ox.graph_from_place('Finland', network_type='drive')
print(type(G1))
fig, ax = ox.plot_graph(G1)
# Out:
# /Users/guorui/anaconda3/envs/urbsim/lib/python3.11/site-packages/osmnx/_overpass.py:211: UserWarning: This area is 220 times your configured Overpass max query area size. It will automatically be divided up into multiple sub-queries accordingly. This may take a long time.
#   multi_poly_proj = utils_geo._consolidate_subdivide_geometry(poly_proj)
# <class 'networkx.classes.multidigraph.MultiDiGraph'>

# %% [markdown]
# ## 2.2 Graph statistics & structure

# %%
# Calculate basic street network metrics and display average circuity
stats = ox.basic_stats(G1)
stats
# Out:
# {'n': 430983,
#  'm': 980414,
#  'k_avg': 4.5496643719125816,
#  'edge_length_total': 482669525.18498105,
#  'edge_length_avg': 492.31194697850196,
#  'streets_per_node_avg': 2.388537366903103,
#  'streets_per_node_counts': {0: 0,
#   1: 146672,
#   2: 1853,
#   3: 251123,
#   4: 31028,
#   5: 282,
#   6: 25},
#  'streets_per_node_proportions': {0: 0.0,
#   1: 0.34031968778350885,
#   2: 0.004299473529118318,
#   3: 0.5826749546965889,
#   4: 0.0719935589106763,
#   5: 0.0006543181517600462,
#   6: 5.800692834752183e-05},
#  'intersection_count': 284311,
#  'street_length_total': 244935299.6350038,
#  'street_segment_count': 515673,
#  'street_length_avg': 474.9818191664171,
#  'circuity_avg': 1.1160921432110993,
#  'self_loop_proportion': 0.009668918093442938}

# %% [markdown]
# ## 2.3 Save road network

# %%
# Save the network diagram to a local GraphML file
ox.save_graphml(G1, filepath='./road_network_files/Finland_drive_network.graphml')
