# %% [markdown]
# **POI Clustering**
#
# *Step1: Get the category corresponding to POIs*
#
# - 1.1 Split raw POIs data
# - 1.2 Add CAT_NUMBER to micode sheet(merged by TRADE_GROUP)
# - **1.3 Add CAT_NUMBER to POI data (merged by MICODE)**
# - 1.4 Retain POI data with CAT_NUMBER between 101 and 115

# %% [markdown]
# # 1 Import package

# %%
import pandas as pd

# %% [markdown]
# # 2 Merge data

# %%
# Read in poi CSV file
input_csv_file = '../../../../data/Locomizer_edited/pois/2023-05_POIs_for_JCD_Finland_(micodes).csv'
df_pois = pd.read_csv(input_csv_file, encoding='utf-8')
# Out:
# /var/folders/k8/5696rnpn6mv66f3rfvm28_b00000gn/T/ipykernel_87148/1354166763.py:3: DtypeWarning: Columns (4,5,17,27) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_pois = pd.read_csv(input_csv_file, encoding='utf-8')

# %%
df_pois.head()
# Out:
#    LATITUDE  LONGITUDE             NAME BRANDNAME FRANCHISE_NAME TRADE_NAME  \
# 0  63.74856   28.67391  PUUKARI TH"," P       NaN            NaN        NaN
# 1  64.58516   24.69568    TIKKALANTIE P       NaN            NaN        NaN
# 2  62.86890   27.63943    GOLF-FUNNY OY       NaN            NaN        NaN
# 3  63.94491   24.93294         LEPOLA I       NaN            NaN        NaN
# 4  61.32062   22.77247  KIIKANOJANTIE P       NaN            NaN        NaN
#
#   ISO3  AREANAME3          AREANAME2 ADD_NUMBER  ...    SIC1  SIC2  \
# 0  FIN    PUUKARI    POHJOIS-KARJALA          1  ...     NaN   NaN
# 1  FIN      RAAHE  POHJOIS-POHJANMAA        NaN  ...     NaN   NaN
# 2  FIN     KUOPIO       POHJOIS-SAVO        NaN  ...  5941.0   NaN
# 3  FIN     NIVALA  POHJOIS-POHJANMAA        119  ...     NaN   NaN
# 4  FIN  SASTAMALA          PIRKANMAA        NaN  ...     NaN   NaN
#
#          SIC8                  SIC8_DESCRIPTION    MICODE  \
# 0         NaN                          BUS STOP  10320302
# 1         NaN                          BUS STOP  10320302
# 2  59410000.0  SPORTING GOODS AND BICYCLE SHOPS  10015941
# 3         NaN                          BUS STOP  10320302
# 4         NaN                          BUS STOP  10320302
#
#                                       TRADE_DIVISION  \
# 0  DIVISION E. - TRANSPORTATION AND PUBLIC UTILITIES
# 1  DIVISION E. - TRANSPORTATION AND PUBLIC UTILITIES
# 2                         DIVISION G. - RETAIL TRADE
# 3  DIVISION E. - TRANSPORTATION AND PUBLIC UTILITIES
# 4  DIVISION E. - TRANSPORTATION AND PUBLIC UTILITIES
#
#                                           GROUP_NAME  \
# 0  LOCAL AND SUBURBAN TRANSIT AND INTERURBAN HIGH...
# 1  LOCAL AND SUBURBAN TRANSIT AND INTERURBAN HIGH...
# 2                               MISCELLANEOUS RETAIL
# 3  LOCAL AND SUBURBAN TRANSIT AND INTERURBAN HIGH...
# 4  LOCAL AND SUBURBAN TRANSIT AND INTERURBAN HIGH...
#
#                             MAIN_CLASS                         SUB_CLASS  \
# 0                PUBLIC TRANSPORT STOP                          BUS STOP
# 1                PUBLIC TRANSPORT STOP                          BUS STOP
# 2  MISCELLANEOUS SHOPPING GOODS STORES  SPORTING GOODS AND BICYCLE SHOPS
# 3                PUBLIC TRANSPORT STOP                          BUS STOP
# 4                PUBLIC TRANSPORT STOP                          BUS STOP
#
#    GLOBAL_ULTIMATE_BUSINESS_NAME
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
#
# [5 rows x 28 columns]

# %%
# Read in micode Excel file
input_excel_file = '../../../../data/Locomizer_edited/micode_sheet_edited.xlsx'
df_micode = pd.read_excel(input_excel_file)

# %%
df_micode.head()
# Out:
#                                      TRADE_DIVISION  \
# 0  Division A. - Agriculture, Forestry, and Fishing
# 1  Division A. - Agriculture, Forestry, and Fishing
# 2  Division A. - Agriculture, Forestry, and Fishing
# 3  Division A. - Agriculture, Forestry, and Fishing
# 4  Division A. - Agriculture, Forestry, and Fishing
#
#                        TRADE_GROUP        CLASS         SUB_CLASS    SIC  \
# 0  Agricultural Production - Crops  Cash Grains             Wheat  111.0
# 1  Agricultural Production - Crops  Cash Grains              Rice  112.0
# 2  Agricultural Production - Crops  Cash Grains              Corn  115.0
# 3  Agricultural Production - Crops  Cash Grains          Soybeans  116.0
# 4  Agricultural Production - Crops  Cash Grains  Cash Grains, nec  119.0
#
#         SIC8    MICODE  SIC8_DESCRIPTION  CAT_NUMBER
# 0  1110000.0  10050111             Wheat         NaN
# 1  1120000.0  10050112              Rice         NaN
# 2  1150000.0  10050115              Corn         NaN
# 3  1160000.0  10050116          Soybeans         NaN
# 4  1190000.0  10050119  Cash grains, nec         NaN

# %%
# Merge data, based on MICODE column
df_merged = df_pois.merge(df_micode[['MICODE', 'CAT_NUMBER']], on='MICODE', how='left')

# %%
df_merged.head()
# Out:
#    LATITUDE  LONGITUDE             NAME BRANDNAME FRANCHISE_NAME TRADE_NAME  \
# 0  63.74856   28.67391  PUUKARI TH"," P       NaN            NaN        NaN
# 1  64.58516   24.69568    TIKKALANTIE P       NaN            NaN        NaN
# 2  62.86890   27.63943    GOLF-FUNNY OY       NaN            NaN        NaN
# 3  62.86890   27.63943    GOLF-FUNNY OY       NaN            NaN        NaN
# 4  62.86890   27.63943    GOLF-FUNNY OY       NaN            NaN        NaN
#
#   ISO3 AREANAME3          AREANAME2 ADD_NUMBER  ... SIC2        SIC8  \
# 0  FIN   PUUKARI    POHJOIS-KARJALA          1  ...  NaN         NaN
# 1  FIN     RAAHE  POHJOIS-POHJANMAA        NaN  ...  NaN         NaN
# 2  FIN    KUOPIO       POHJOIS-SAVO        NaN  ...  NaN  59410000.0
# 3  FIN    KUOPIO       POHJOIS-SAVO        NaN  ...  NaN  59410000.0
# 4  FIN    KUOPIO       POHJOIS-SAVO        NaN  ...  NaN  59410000.0
#
#                    SIC8_DESCRIPTION    MICODE  \
# 0                          BUS STOP  10320302
# 1                          BUS STOP  10320302
# 2  SPORTING GOODS AND BICYCLE SHOPS  10015941
# 3  SPORTING GOODS AND BICYCLE SHOPS  10015941
# 4  SPORTING GOODS AND BICYCLE SHOPS  10015941
#
#                                       TRADE_DIVISION  \
# 0  DIVISION E. - TRANSPORTATION AND PUBLIC UTILITIES
# 1  DIVISION E. - TRANSPORTATION AND PUBLIC UTILITIES
# 2                         DIVISION G. - RETAIL TRADE
# 3                         DIVISION G. - RETAIL TRADE
# 4                         DIVISION G. - RETAIL TRADE
#
#                                           GROUP_NAME  \
# 0  LOCAL AND SUBURBAN TRANSIT AND INTERURBAN HIGH...
# 1  LOCAL AND SUBURBAN TRANSIT AND INTERURBAN HIGH...
# 2                               MISCELLANEOUS RETAIL
# 3                               MISCELLANEOUS RETAIL
# 4                               MISCELLANEOUS RETAIL
#
#                             MAIN_CLASS                         SUB_CLASS  \
# 0                PUBLIC TRANSPORT STOP                          BUS STOP
# 1                PUBLIC TRANSPORT STOP                          BUS STOP
# 2  MISCELLANEOUS SHOPPING GOODS STORES  SPORTING GOODS AND BICYCLE SHOPS
# 3  MISCELLANEOUS SHOPPING GOODS STORES  SPORTING GOODS AND BICYCLE SHOPS
# 4  MISCELLANEOUS SHOPPING GOODS STORES  SPORTING GOODS AND BICYCLE SHOPS
#
#    GLOBAL_ULTIMATE_BUSINESS_NAME  CAT_NUMBER
# 0                            NaN         NaN
# 1                            NaN         NaN
# 2                            NaN         NaN
# 3                            NaN         NaN
# 4                            NaN         NaN
#
# [5 rows x 29 columns]

# %% [markdown]
# # 3 Export dataframe

# %%
# Save the merged DataFrame to a new CSV file
output_csv_file = '../../../../data/Locomizer_edited/pois/add_category_number/2023-05_POIs_MICODE_CAT_NUMBER.csv'
df_merged.to_csv(output_csv_file, index=False, encoding='utf-8')
